# %% [markdown]
# 1. Display the board
# Consider that the board isn't only a graphical element, but needs to support and hold user input

# %%
board=[' ' for x in range(10)]
board
# Out:
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ']

# %%
def printBoard(board):
    #row 1
    print('   |   |   ')
    print(' '+board[1]+' | '+board[2]+' | '+board[3]+' ')
    print('   |   |   ')
    print('___________')
    print()
    #row 2
    print('   |   |   ')
    print(' '+board[4]+' | '+board[5]+' | '+board[6]+' ')
    print('   |   |   ')
    print('___________')
    print()
    #row 3
    print('   |   |   ')
    print(' '+board[7]+' | '+board[8]+' | '+board[9]+' ')
    print('   |   |   ')
    print('___________')

# %% [markdown]
# 2. Handle player input and mark it on the board
# - User input restricted to position, no mark. Mark is assigned to player in the beginning.
# - invalid characters
# - only if valid choice (1-9) and cell is free mark position

# %%
def insertMark(mark,pos):#user's mark, and the position
    board[pos] = insert

# %% [markdown]
# 3. Validate player input
# Check for occupied or invalid positions, mark the board, and check for win condition (3-in-a-row, or ran out of space)

# %%
def isSpaceFree(pos):
    return(board[pos]==' ')

# %%
def isBoardFull(board):
    if board.count(' ')>=1:
        return(False)
    else:
        return(True)

# %%
def isWinner(board,letter):
    return((board[1] == letter and board[2] == letter and board[3]== letter)
           or
           (board[4] == letter and board[5] == letter and board[6]== letter)
           or
           (board[7] == letter and board[8] == letter and board[9]== letter)
           or
           (board[1] == letter and board[4] == letter and board[7]== letter)
           or
           (board[2] == letter and board[5] == letter and board[8]== letter)
           or
           (board[3] == letter and board[6] == letter and board[9]== letter)
           or
           (board[1] == letter and board[5] == letter and board[9]== letter)
           or
           (board[3] == letter and board[5] == letter and board[7]== letter)
    )

# %% [markdown]
# 4. Make the computer move

# %% [markdown]
# 5. Keep the game running until an end condition is met

# %% [markdown]
# 6. Check for win or tie:
#    - Three consecutive marks (horizontal, vertical, diagonal)
#    - No empty spaces left on the board

# %% [markdown]
# 7. Announce the winner or tie

# %% [markdown]
# 8. Offer a replay option
